# %% [markdown]
# <a href="https://colab.research.google.com/github/MrEduardo15/Estrutura-de-dados/blob/main/Curso_Visu_de_dados_DELLdell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos de Barras com matplotlib

# %%
# ==========================================
# ETAPA 1: IMPORTAÇÃO DA BIBLIOTECA
# ==========================================
# Importamos o pandas e damos o apelido de 'pd' para facilitar
import pandas as pd

print("--- Etapa 1: Pandas importado com sucesso! ---\n")


# ==========================================
# ETAPA 2: CRIAÇÃO DA SERIES
# ==========================================
# Criamos uma lista comum do Python com números de 1 a 5
lista_numeros = [1, 2, 3, 4, 5]

# Convertemos essa lista em uma Series do Pandas
s = pd.Series(lista_numeros)

# Exibimos a Series inteira na tela
print("--- Etapa 2: Exibindo a Series criada ---")
print(s)
print("\n")


# ==========================================
# ETAPA 3: ACESSANDO OS ATRIBUTOS
# ==========================================
# Pegamos apenas os valores contidos na Series (ignorando o índice)
valores_da_series = s.values

print("--- Etapa 3: Exibindo apenas os valores ---")
print(valores_da_series)
print("\n")


# ==========================================
# ETAPA 4: ACESSANDO UM ELEMENTO ESPECÍFICO
# ==========================================
# Buscamos o elemento que está na quarta posição (índice 3, pois começa no 0)
quarto_elemento = s[3]

print("--- Etapa 4: Exibindo o elemento do índice [3] ---")
print(quarto_elemento)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

categorias = ['A','B','C','D']
valores = [10, 20, 15, 5]
plt.figure(figsize=(5, 3)) #Essa é qual define o tamanho do codigo (comprimento e altura)
plt.bar(categorias,valores,color ='darkred')
plt.xlabel('Grupos')
plt.ylabel('Tamanho')
plt.title('Meu primeiro gráfico de barras')
plt.show()

# %% [markdown]
# Codigo com as funções

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

filmes_uri = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_uri)

def head():
  print("Esse é o metodo head(Responsalvel por mostrar as prieiras 5 linhas do codigo)")
  print(tabulate(filmes.head(), headers="keys", tablefmt="grid"))

def describe():
  print("ESSE É O METODO DESCRIBE(responsavel por mostrar as medidas estatísticas dos atributos quantitativos que são o Budget_M e o Worldwide_Gross_M)"
)
  print(tabulate(filmes.describe(), headers="keys", tablefmt="grid"))

def groupby():
  print("Esse é o medoto groupby que permite agrupar os dados em relação a um atributo e aplicar uma operação matemática sobre eles.")
  print(tabulate(filmes.groupby(by='Genre').count(), headers="keys", tablefmt="grid"))


head()
describe()
groupby()

# %% [markdown]
# Codigo separados

# %%
filmes_uri = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_uri)
filmes.head()

# %%
filmes_uri = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_uri)
filmes.describe()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate

filmes_uri = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_uri)
contagens = filmes.groupby(by='Genre').count()
contagens
plt.figure(figsize=(10, 3))
plt.bar(contagens.index, contagens['Worldwide_Gross_M'])
plt.show()

# %% [markdown]
# # Grafico de barras seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="darkgrid")
plt.figure(figsize=(10, 3))

#sns.countplot(x="Genre", data=filmes)

#countplt --> contando o número de elementos de um determinado grupo.
plt.title('Quantidade de filmes por gênero')
sns.countplot(x="Genre", color = 'r', data=filmes)
#Deixar o grafico horizontal
#sns.countplot(y="Genre", color = 'r', data=filmes)

#plt.title('Bilheteria média por gênero')
#Usando a função barplot()
#sns.barplot(x="Genre", y="Worldwide_Gross_M", color = 'b', ci = ‘sd’, data=filmes)

#sns.barplot(x="Genre",y ="Worldwide_Gross_M", color='purple',estimator = sum, errorbar = None, data=filmes) #caso queira mudar para barras verticais mudar o eixo

plt.show()

# %% [markdown]
# Em gráficos de barras simples, cada posição ao longo de um eixo representa uma categoria e uma barra é desenhada mapeando um valor para essa categoria. Em gráficos de barras agrupadas, as categorias também estão dispostas ao longo de um eixo, mas existe mais de uma barra para cada categoria. Essas barras em cada categoria podem ser distinguidas pela cor e representam outro atributo categórico.
#
# Para gerar esse tipo de gráfico no seaborn, é muito simples. Basta atribuir uma categoria ao parâmetro hue nas funções que você já utilizou. Hue significa matiz de uma cor. Ou seja, a nova categoria será mapeada na cor das barras. Confira o exemplo de código a seguir e o resultado de sua execução.
#
# E então, você achou simples? As linhas 1 e 2 configuram o tamanho e o título da figura, como já feito anteriormente. Na linha 3 é chamada a função countplot() de maneira muito similar ao que já foi feito, passando o valor ‘Year’ para o parâmetro x. Ou seja, os anos serão mapeados na posição do eixo x. A novidade é o parâmetro hue, que recebe a coluna ‘Genre’, significando que o gênero dos filmes será mapeado nas cores das barras.
#
# Note algumas particularidades dos dados: só existe um filme de fantasia e um de romance nesses dados, e são de 2011. O filme de suspense é de 2008. A quantidade de filmes de ação varia de dois a três a cada ano. E se você quiser visualizar a média de bilheteria por gênero em cada ano?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,5))
plt.title('Filmes por gênero em cada ano')
sns.countplot(x="Year", hue= 'Genre', data=filmes)
plt.show()

# %% [markdown]
# Verificar ultimo slide é o 3 da aula 2.1
#
# A mudança nesse código em relação ao anterior ocorre somente na linha 3. Note que, na linha 3, a função barplot() é chamada passando como parâmetro x o ‘Year’ e o parâmetro y como o ‘Worldwide_Gross_M’, de forma similar ao já feito anteriormente. A grande diferença é que é passado o atributo ‘Genre’ para o parâmetro hue.
#
# Essa visualização esclarece mais o comportamento das bilheterias. Lembre que no geral a bilheteria de filmes de fantasia era maior do que os de ação. Mas isso ocorreu porque só existe um filme de fantasia, que obteve uma boa bilheteria. Já os filmes de ação, que são maioria nesse conjunto de dados, tiveram um desempenho variável ao longo dos anos, mas tiveram em média uma grande bilheteria no ano de 2009. Que outras considerações você pode fazer a partir dessa visualização?

# %%
plt.figure(figsize=(15,8))
plt.title('Média de bilheteria por gênero em cada ano')
sns.barplot(x="Year", y = 'Worldwide_Gross_M' , errorbar = None, hue= 'Genre', data=filmes)
plt.show()

# %% [markdown]
# Gráfico de pizza

# %%
import pandas as ps
import matplotlib.pyplot as plt

especie = ['Cachorro', 'Gato', 'Pássaro']
quantidade = [110,90,30]
plt.title('Proporção de espécies')
# ao adicionar o autopct = '%1.2f%%' para adcionar as porcentagens
plt.pie(x=quantidade, labels = especie, autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# Existe ainda uma variação do gráfico de pizza que é mais apreciada em algumas situações. Ele é chamado gráfico de rosca (em inglês, donut chart). Em essência, é um gráfico de pizza com área central removida. Por isso, acontece uma diferença de percepção, pois, ao invés de avaliarmos áreas de fatias, estamos avaliando ângulos, o que pode ser mais fácil de perceber, principalmente, quando há várias categorias. Agora, vamos ilustrar isso com dois exemplos, certo? Confira, no exemplo a seguir, um gráfico de pizza das raças de cães atendidos na clínica veterinária fictícia dos exemplos anteriores:

# %%
races = ['Poodle', 'Golden Retriver', 'Bulldog', 'Pastor Alemão', 'Labrador', 'Sem Raça Definida']
quant_races = [25,15,5,20,25,10]
plt.title('Proporção de raças de cães')
plt.pie(x=quant_races, labels = races, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# Perceba que o matplotlib permite criar gráficos não relacionados a dados. Na linha 1, é criado o gráfico e configurado os seus parâmetros, assim como feito anteriormente. Devido a isso, note que, na chamada da função pie(), foram usados dois parâmetros não utilizados antes: startangle, que define o ângulo de início; e pctdistance, que define a distância do texto em relação ao centro do círculo. Nas linhas 2, 3 e 4, é criado um círculo branco que é sobreposto ao gráfico de pizza. Qual desses dois exemplos você achou melhor para perceber as proporções? O gráfico de rosca não necessariamente será sempre preferível ao gráfico de pizza. De fato, em visualização de dados, não existe um tipo de visualização que sempre funciona em toda ocasião, pois tanto o gráfico de pizza quanto o de rosca possuem fraquezas que limitam o seu uso em algumas situações. Então, agora, você vai conhecer melhor essas fraquezas, preparado? Ótimo!

# %%
plt.pie(x=quant_races, labels=races, autopct='%1.1f%%',startangle=90, pctdistance=0.85)
my_circle=plt.Circle((0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Proporção de raças de cães')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
plt.style.use('seaborn-darkgrid')
plt.title('Distribuição de áreas dos imóveis')
plt.hist(df['area'])
plt.show()

# %% [markdown]
# https://leadfortaleza.com.br/ead/courses/96601506629915/lessons/102192363892591/webaula/102192363894696
# Revisar a aula

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")


uri = 'https://raw.githubusercontent.com/cabrau/curso-analise-visualizacao-dados-python/master/room_data.txt'
room = pd.read_csv(uri)
room.head()

# %% [markdown]
#  Variação da temperatura do quarto ao longo dos dias.
#  Mapeando pelo eixo y a temperatura:

# %%
plt.figure(figsize=(10,5))
plt.title('Variação da temperatura ao longo do tempo')
sns.scatterplot(x="date", y="Temperature", data=room)
plt.show()

# %% [markdown]
# Para criar um grafico de linha conecta os pontos, facilitando a a visualização de uma sequencia

# %%
#room['date'] = pd.to_datetime(room['date']) # a coluna ‘date’ é convertida ao tipo datetime, utilizado em Python para representar datas e horários.
plt.figure(figsize=(10,5))
plt.title('Variação da temperatura ao longo do tempo')
sns.lineplot(x="date", y="Temperature", data=room) # lineplot(), passando como parâmetros para o eixo x a coluna ‘date’, para o eixo y a coluna ‘Temperatura’, e indicando que os dados estão na variável room.
plt.show()

# %% [markdown]
# Dados coletados pelo Banco Mundial e contém informações sobre a incidência do vírus HIV ao longo de mais de 20 anos para diversos países.

# %%
hiv_uri = 'https://raw.githubusercontent.com/cabrau/curso-analise-visualizacao-dados-python/master/hiv_data.txt'
hiv = pd.read_csv(hiv_uri)
hiv.head()

# %% [markdown]
# taxa de HIV variou no mundo todo ao redor dos anos

# %%
plt.figure(figsize=(10,5))
plt.title('Variação da taxa média de HIV global')
sns.lineplot(x="date", y="HIV Rate", data=hiv)
plt.show()

# %% [markdown]
# As taxas médias por nível de renda dos países

# %%
plt.figure(figsize=(10,5))
plt.title('Variação da taxa média de HIV para níveis de renda')
sns.lineplot(x="date", y="HIV Rate", hue = 'country', legend = False, data=hiv)
plt.show()

# %% [markdown]
# ## Aula 4.1 topico 1

# %% [markdown]
# gráfico de dispersão categórico

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

titanic = sns.load_dataset("titanic") # carregar os dados em um DataFrame de pandas, através da função load_dataset do seaborn
titanic.head()

plt.figure(figsize=(10,5))
plt.title('Idade de passageiros em cada classe')
sns.stripplot(x="class", y="age", data=titanic) #Cria o gráfico de tiras
plt.show()

# %% [markdown]
# Grafico de enxame

# %%
plt.figure(figsize=(10,5))
plt.title('Idade de passageiros em cada classe')
sns.swarmplot(x="class", y="age",hue = 'sex', data=titanic) # Organiza o grafico de linhas, não sobrepondo-os
plt.show()

# %% [markdown]
#  para visualizar as duas variáveis, simultaneamente, é criar uma grade de visualizações, usando a função catplot().

# %%
sns.catplot(x="pclass", y="age", hue = 'sex', col = 'survived', kind = 'swarm', data=titanic)
plt.show()

# %% [markdown]
# Função que cria gráficos de caixa no seaborn é boxplot().

# %%
plt.figure(figsize=(8,5))
plt.title('Idade de passageiros em cada classe')
sns.boxplot(x="class", y="age",hue = 'sex', data=titanic)
plt.show()

# %% [markdown]
# A diferença comparado a boxplt, é queao usar boxenplot() representa os bigodes com espessuras que permitem uma melhor percepção visual das quantidades de dados nas caudas.

# %%
plt.figure(figsize=(15,8))
plt.title('Idade de passageiros em cada classe')
sns.boxenplot(x="class", y="age", hue = 'sex', data=titanic) #posso usar um col e kind para separar
plt.show()

# %% [markdown]
# Grafico de Violino

# %%
plt.figure(figsize=(8,5))
plt.title('Idade de passageiros em cada classe')
sns.violinplot(x="class", y="age", data=titanic)
plt.show()

# %% [markdown]
# Combinando com swarplot

# %%
plt.figure(figsize=(8,5))
plt.title('Idade de passageiros em cada classe')
sns.violinplot(x="class", y="age", data=titanic)# podemos adicionar
# hue = 'sex', split = True
sns.swarmplot(x="class", y="age",color = 'black', size = 3, data=titanic)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title('Idade de passageiros em cada classe')
sns.violinplot(x="class", y="age",hue = 'sex', split = True,  data=titanic)
plt.show()

# %% [markdown]
# ## Distribuição Bivariada
#  A distribuição conjunta de duas variáveis chama-se distribuição bivariada e pode ser visualizada através de uma combinação entre histogramas e gráfico de dispersão.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

iris = sns.load_dataset("iris")
iris.head()
sns.jointplot(x="sepal_length", y="petal_length", kind = 'kde', data=iris)

# %% [markdown]
# Dristibuição conjuntas par a par

# %% [markdown]
# O pairplot() é uma função da biblioteca Seaborn em Python que cria uma grade de gráficos para visualizar relações entre todas as variáveis numéricas de um conjunto de dados de uma só vez. Ele gera gráficos de dispersão para pares de variáveis e histogramas na diagonal principal.

# %%
sns.pairplot(iris)

# %% [markdown]
# ## Aula 5

# %% [markdown]
# Topico 1- Primeiros passos com Kibana
